# %%
import pickle
import pandas as pd
import json

# %%
df = pd.read_pickle('savedDF-BRI.pickle')

# %%
heritage = pd.read_excel('heritage-data-2019.xls')
heritage.head()
# Out:
#    CountryID Country Name      WEBNAME                        Region  \
# 0          1  Afghanistan  Afghanistan                  Asia-Pacific
# 1          2      Albania      Albania                        Europe
# 2          3      Algeria      Algeria  Middle East and North Africa
# 3          4       Angola       Angola            Sub-Saharan Africa
# 4          5    Argentina    Argentina                      Americas
#
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# 4       148.0         26.0        52.2             47.8
#
#    Judical Effectiveness  Government Integrity  ...      Country  \
# 0                   29.6                  25.2  ...  Afghanistan
# 1                   30.6                  40.4  ...      Albania
# ...

# %%
def get_rank_score(name):
    result = heritage.loc[heritage['Country Name'] == name]
    if len(result) == 0:
        return (None,None)
    else:
        rank = result.iloc[0]['World Rank']
        score = result.iloc[0]['2019 Score']
        return (rank, score)
    
for index, name in df['Country (according to CN Gov):'].items():
    rank, score = get_rank_score(name)
    if rank != None:
        print(name, rank,score)
        df['']
    else:
        print('no data for',name)
# Out:
# Afghanistan 152.0 51.5
# Albania 52.0 66.5
# Armenia 47.0 67.7
# Azerbaijan 60.0 65.4
# Bahrain 54.0 66.4
# Bangladesh 121.0 55.6
# Belarus 104.0 57.9
# Bhutan 74.0 62.9
# Bosnia and Herzegovina 83.0 61.9
# no data for Brunei
# Bulgaria 37.0 69.0
# Cambodia 105.0 57.8
# China 100.0 58.4
# Croatia 86.0 61.4
# Czech Republic 23.0 73.7
# no data for East Timor
# Egypt 144.0 52.5
# Estonia 15.0 76.6
# no data for France (Not BRI)
# Georgia 16.0 75.9
# no data for Germany (not BRI)
# Hungary 64.0 65.0
# India 129.0 55.2
# Indonesia 56.0 65.8
# Iran 155.0 51.1
# Iraq nan nan
# Israel 27.0 72.8
# Jordan 53.0 66.5
# Kazakhstan 59.0 65.4
# Kuwait 90.0 60.8
# no data for Kyrgyzstan
# Laos 110.0 57.4
# Latvia 35.0 70.4
# Lebanon 154.0 51.1
# Lithuania 21.0 74.2
# Macedonia 33.0 71.1
# Malaysia 22.0 74.0
# Maldives 141.0 53.2
# Moldova 97.0 59.1
# Mongolia 126.0 55.4
# Montenegro 92.0 60.5
# no data for Myanmar
# Nepal 136.0 53.8
# Oman 88.0 61.0
# Pakistan 131.0 55.0
# Philippines 70.0 63.8
# ...

# %%
pd.to_pickle('savedDF-BRI.pickle')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2b6846b93484> in <module>
# ----> 1 df = pd.to_pickle('savedDF-BRI.pickle')
#
# TypeError: to_pickle() missing 1 required positional argument: 'path'
